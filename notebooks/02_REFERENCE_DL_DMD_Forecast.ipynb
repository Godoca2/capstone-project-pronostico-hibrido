# %% [markdown]
# # ⚠️ NOTEBOOK DE REFERENCIA - NO PARTE DEL PIPELINE PRINCIPAL
#
# ---
#
# ## 🔴 ADVERTENCIA IMPORTANTE
#
# Este notebook es una **referencia histórica** del trabajo del **Prof. Herrera** y utiliza **datos sintéticos** con fines didácticos.
#
# **NO forma parte del pipeline principal de modelado** que usa exclusivamente datos ERA5 reales.
#
# ### Características de este notebook:
#
# - **Propósito**: Ejemplo académico de implementación AE+DMD
# - **Datos**: Utiliza `precipitation_data.npy` (datos sintéticos/simulados)
# - **Reproducibilidad**: Usa `np.random.seed(124)` para generar ruido artificial
# - 🔴 **Estado**: NO ejecutar como parte del flujo principal
#
# ### Pipeline Principal (con datos ERA5 reales):
#
# Para el pipeline de producción con datos ERA5 reales, usar:
#
# 1. `03_AE_DMD_Training.ipynb` - Entrenamiento AE+DMD con ERA5
# 2. `04_Advanced_Metrics.ipynb` - Métricas avanzadas
# 3. `05_KoVAE_Test.ipynb` - Modelo KoVAE
# 4. `06_Hyperparameter_Experiments.ipynb` - Optimización
# 5. `07_DMD_Interpretability.ipynb` - Interpretabilidad
# 6. `08_CHIRPS_Validation.ipynb` - Validación satelital
#
# ---
#
# **Fecha de referencia**: Material original Prof. Herrera
# **Renombrado**: 23 nov 2025 (auditoría pipeline)
# **Razón**: Separar claramente notebooks de referencia de pipeline principal
#
# ---

# %%
# CONTEXTO DEL PRONÓSTICO AE-DMD
"""Notebook de modelado híbrido:
1. Carga matriz estaciones (precipitation_data.npy o CSV fallback).
2. Normaliza y separa train / holdout.
3. Entrena Autoencoder (compresión espacial) y aplica DMD en latente.
4. Genera pronóstico multivariado y lo compara contra persistencia.
5. Exporta predicciones y métricas para análisis posterior.
Herramientas: TensorFlow/Keras, PyDMD, NumPy, Pandas, Matplotlib.
"""

# %% [markdown]
# # 02_DL_DMD_Forecast
#
# Pronóstico de series de tiempo de precipitación con autoencoder y DMD

# %%
import pandas as pd
import numpy as np

# Leer los datos desde el archivo CSV
# Supongamos que el archivo CSV tiene N filas (observaciones) y P columnas (estaciones)
data_df = pd.read_csv(r'D:\11_Entorno_Desarrollo\UDD\captone_project\CAPSTONE_PROJECT\data\raw\precipitation_test.csv')

# Convertir el DataFrame a un array de NumPy
data = data_df.values

# Verificar la forma de los datos
print(data.shape) # Esto imprimirá (N, P), donde N es el número de observaciones y P es el número de estaciones.
# Guardar los datos en formato .npy
np.save('precipitation_data.npy', data)
# Out:
# (1826, 30)

# %%
# Instalar pydmd si no está disponible
#%pip install pydmd

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, RepeatVector, Dense
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from pydmd import DMD

# Parámetros del espacio latente
latent_dim = 100 # Ajustar la dimensión del espacio latente

# %%
# 1. Cargar y preparar los datos
X = np.load('precipitation_data.npy') # [samples, stations]

# Normalizar los datos
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Definir el número de características (dimensión multivariada)
n_features = X.shape[1] # Dimensión de las series multivariadas
X_scaled = X_scaled[:, :n_features] # Asegurarse de que X_scaled tiene m=150 series

# Reshape para el autoencoder
X_scaled = X_scaled.reshape(-1, 1, n_features)

# %%
# 2. Definir el Autoencoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, RepeatVector, Dense

timesteps = X_scaled.shape[1]

input_layer = Input(shape=(timesteps, n_features))
encoded = LSTM(64, activation='relu', return_sequences=False)(input_layer) # Encoder
encoded = Dense(latent_dim, activation='relu')(encoded) # Latent space
decoded = Dense(64, activation='relu')(encoded) # Decoder
decoded = RepeatVector(timesteps)(decoded)
decoded = LSTM(n_features, activation='sigmoid', return_sequences=True)(decoded) # Output layer

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# Entrenar el autoencoder
autoencoder.fit(X_scaled, X_scaled, epochs=50, batch_size=1, shuffle=True)
# Out:
# Epoch 1/50
# 1826/1826 [==============================] - 20s 10ms/step - loss: 0.0041
# Epoch 2/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 9.2738e-04
# Epoch 3/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 7.8611e-04
# Epoch 4/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 5.7983e-04
# Epoch 5/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 5.2015e-04
# Epoch 6/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 4.8619e-04
# Epoch 7/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 4.6569e-04
# Epoch 8/50
# 1826/1826 [==============================] - 17s 9ms/step - loss: 3.9990e-04
# Epoch 9/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 3.8818e-04
# Epoch 10/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 3.7363e-04
# Epoch 11/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 3.6573e-04
# Epoch 12/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 3.2892e-04
# Epoch 13/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 3.2356e-04
# Epoch 14/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 3.1185e-04
# Epoch 15/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 2.6429e-04
# Epoch 16/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 2.7820e-04
# Epoch 17/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.7607e-04
# Epoch 18/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 2.5005e-04
# Epoch 19/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 2.6087e-04
# Epoch 20/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 2.6318e-04
# Epoch 21/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.6316e-04
# Epoch 22/50
# 1826/1826 [==============================] - 17s 9ms/step - loss: 2.4746e-04
# Epoch 23/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.3138e-04
# Epoch 24/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.5439e-04
# Epoch 25/50
# 1826/1826 [==============================] - 17s 9ms/step - loss: 2.5486e-04
# Epoch 26/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.2757e-04
# Epoch 27/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.4307e-04
# Epoch 28/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.3828e-04
# Epoch 29/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.1562e-04
# Epoch 30/50
# 1826/1826 [==============================] - 17s 9ms/step - loss: 2.2209e-04
# Epoch 31/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.2655e-04
# Epoch 32/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.3253e-04
# Epoch 33/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 1.9823e-04
# Epoch 34/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.2731e-04
# Epoch 35/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.0849e-04
# Epoch 36/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 2.1757e-04
# Epoch 37/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 2.0913e-04
# Epoch 38/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 1.9627e-04
# Epoch 39/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 1.9896e-04
# Epoch 40/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 1.9957e-04
# Epoch 41/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 2.0049e-04
# Epoch 42/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 1.9505e-04
# Epoch 43/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 1.8762e-04
# Epoch 44/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 1.9258e-04
# Epoch 45/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 2.1398e-04
# Epoch 46/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 1.7750e-04
# Epoch 47/50
# 1826/1826 [==============================] - 16s 9ms/step - loss: 1.8770e-04
# Epoch 48/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 1.7747e-04
# Epoch 49/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 1.8292e-04
# Epoch 50/50
# 1826/1826 [==============================] - 15s 8ms/step - loss: 1.8426e-04

# %%
# 6. Verificar las reconstrucciones del autoencoder
X_reconstructed_new = autoencoder.predict(X_scaled)

# Revertir el reshape y la normalización
X_reconstructed_new = X_reconstructed_new.reshape(-1, n_features)
X_scaled = X_scaled.reshape(-1, n_features)
X_reconstructed_new = scaler.inverse_transform(X_reconstructed_new)
X_scaled = scaler.inverse_transform(X_scaled)

# 6.1. Graficar las series originales y reconstruidas para comparar

# Definir el número de estaciones a mostrar en las gráficas
num_stations_to_plot = 5 # Cambiar este valor para regular el número de estaciones que se muestran

plt.figure(figsize=(12, 8))
for i in range(min(n_features, num_stations_to_plot)):
 plt.subplot(num_stations_to_plot, 1, i + 1)
 plt.plot(X_scaled[:, i], label='Original')
 plt.plot(X_reconstructed_new[:, i], label='Reconstrucción')
 plt.title(f'Estación {i + 1}')
 plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 58/58 [==============================] - 1s 3ms/step

# %%
#Guardar los pesos del autoencoder
autoencoder.save_weights('autoencoder_weights.h5')

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, RepeatVector
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from pydmd import DMD
import pandas as pd

# Parámetros
#latent_dim = 100 # Dimensión del espacio latente
svd_rank = int(latent_dim / 1) # SVD rank para DMD
k = 300 # Horizonte de predicción
ruido_ampl =1* 1e-2 # Amplitud del ruido a agregar
delay = 0 # Tamaño del retraso (ventana de tiempo)

# Establecer semilla para reproducibilidad
seed = 124
np.random.seed(seed)

# 1. Cargar y preparar los datos
X = np.load('precipitation_data.npy') # [samples, stations]

# Normalizar los datos
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape para el autoencoder
n_features = X_scaled.shape[1]
X_scaled = X_scaled.reshape(-1, 1, n_features)

# 2. Definir el Autoencoder y cargar los pesos
timesteps = X_scaled.shape[1]
input_layer = Input(shape=(timesteps, n_features))
encoded = LSTM(64, activation='relu', return_sequences=False)(input_layer) # Encoder
encoded = Dense(latent_dim, activation='relu')(encoded) # Latent space
decoded = Dense(64, activation='relu')(encoded) # Decoder
decoded = RepeatVector(timesteps)(decoded)
decoded = LSTM(n_features, activation='sigmoid', return_sequences=True)(decoded) # Output layer

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# Cargar los pesos entrenados previamente
autoencoder.load_weights('autoencoder_weights.h5')

# 3. Obtener la representación latente
encoder_model = Model(inputs=input_layer, outputs=encoded)
X_latent = encoder_model.predict(X_scaled).reshape(-1, latent_dim) # Dimensión: (num_samples, latent_dim)

# 4. Aplicar DMD a la representación latente
dmd = DMD(svd_rank=svd_rank) # Ajustar el svd_rank para DMD
dmd.fit(X_latent.T) # Ajustar DMD

# 5. Realizar predicción con k pasos hacia adelante usando DMD y ventana de retraso
X_pred_latent = X_latent[-delay:, :].T # Inicializar con la ventana de retraso

for _ in range(k):
 next_step = dmd.predict(X_pred_latent[:, -1].reshape(-1, 1)).real
 next_step += ruido_ampl * np.random.randn(latent_dim, 1) # Agregar ruido pequeño
 X_pred_latent = np.hstack((X_pred_latent, next_step))

X_pred_latent = X_pred_latent[:, delay:] # Quitar los vectores originales de la ventana de retraso

# 6. Reconstruir la serie predicha
decoder_model = Model(inputs=encoded, outputs=decoded)
X_pred_latent_reconstructed = []

for i in range(k):
 latent_segment = X_pred_latent[:, i].reshape(1, -1)
 reconstruction = decoder_model.predict(latent_segment).reshape(-1, n_features)
 X_pred_latent_reconstructed.append(reconstruction)

X_pred_latent_reconstructed = np.vstack(X_pred_latent_reconstructed)

# Invertir la normalización
X_pred_latent_reconstructed = scaler.inverse_transform(X_pred_latent_reconstructed)
# Out:
# 58/58 [==============================] - 0s 4ms/step
# c:\Users\cesar.godoy\anaconda3\envs\capstone\lib\site-packages\pydmd\snapshots.py:73: UserWarning: Input data condition number inf. Consider preprocessing data, passing in augmented data
# matrix, or regularization methods.
#   warnings.warn(
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 56ms/step

# %%
# 7. Graficar los resultados
import matplotlib.dates as mdates

# 1. Gráfico de series temporales con fechas
num_stations_to_plot = 1 # Número de estaciones a visualizar
start_date = "2018-01-01" # Fecha de inicio

# Generar fechas para el eje x
dates = pd.date_range(start=start_date, periods=X.shape[0] + X_pred_latent_reconstructed.shape[0])

plt.figure(figsize=(12, 8))
s=0
# Graficar cada estación
for i in range(num_stations_to_plot):
 plt.subplot(num_stations_to_plot, 1, i + 1)
 plt.plot(dates[:X.shape[0]], X[:, i+ s], label='Original')
 plt.plot(dates[X.shape[0]:], X_pred_latent_reconstructed[:, i], label='Predicción extendida')
 plt.title(f'Estación {i+s + 1}')
 plt.legend()

 # Formatear las fechas en el eje x
 plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
 plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3)) # Espaciar las marcas de fechas cada 3 meses
 plt.gcf().autofmt_xdate()

plt.tight_layout()
plt.show()

# %%
# 8. Graficar el último vector latente y las predicciones sucesivas
num_vectors_to_plot = 10 # Número de vectores latentes a visualizar
plt.figure(figsize=(10, 6))
plt.plot(X_latent[-1, :], label='Último vector latente')

for idx in range(min(k, num_vectors_to_plot)):
 plt.plot(X_pred_latent[:, idx], label=f'Predicción {idx + 1}')

plt.title('Último vector latente y predicciones sucesivas')
plt.xlabel('Dimensión del vector latente')
plt.ylabel('Valor')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
